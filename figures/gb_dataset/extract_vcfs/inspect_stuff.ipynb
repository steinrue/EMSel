# %%
import numpy
import matplotlib.pyplot as plt
import pandas
import scipy.stats
import scipy
import collections

# %%
def loadAnnotationFile (annoFile):

    # read it
    anno = pandas.read_csv (annoFile, sep='\t', low_memory=False)

    # reduce the column names
    # fuse first two names, or take the only one
    newColumns = []
    for c in anno.columns:
        fields = c.split()
        if (len(fields) <= 1):
            # just this one
            newColumns.append (fields[0])
        elif ((fields[0] == "SNPs") and (fields[1] == "hit")):
            # this one a bit special
            if any([x == '1240k' for x in fields]):
                newColumns.append (f"{fields[0]}_{fields[1]}_1240k")
            elif any([x == 'HO' for x in fields]):
                newColumns.append (f"{fields[0]}_{fields[1]}_HO")
            elif any([x == '3.2M' for x in fields]):
                newColumns.append (f"{fields[0]}_{fields[1]}_3.2M")
            elif any([x == 'non-padded' for x in fields]):
                newColumns.append (f"{fields[0]}_{fields[1]}_non-padded")
            else:
                # this should be ok for version 50.0?
                newColumns.append (f"{fields[0]}_{fields[1]}")
        elif ((fields[0] == "Y") and (fields[1] == "haplogroup")):
            # this one's special too
            if any([x == 'terminal' for x in fields]):
                newColumns.append (f"{fields[0]}_{fields[1]}_terminal")
            elif any([x == 'ISOGG' for x in fields]):
                if (any([x == 'curation' for x in fields])):
                    newColumns.append (f"{fields[0]}_{fields[1]}_ISOGG_curation")
                else:
                    newColumns.append (f"{fields[0]}_{fields[1]}_ISOGG")
            else:
                assert (False)
        elif ((fields[0] == "Xcontam") and (fields[1] == "ANGSD")):
            # many special snowflakes
            if any([x == 'SNPs' for x in fields]):
                newColumns.append (f"{fields[0]}_{fields[1]}SNPs")
            elif any([x == 'MOM' for x in fields]):
                if (any([x == 'point' for x in fields])):
                    newColumns.append (f"{fields[0]}_{fields[1]}_point")
                elif (any([x == 'Z-score' for x in fields])):
                    newColumns.append (f"{fields[0]}_{fields[1]}_Z-score")
                elif (any([x == 'CI' for x in fields])):
                    newColumns.append (f"{fields[0]}_{fields[1]}_CI")
                else:
                    assert (False)
            else:
                assert (False)
        else:
            # fuse first two
            newColumns.append (f"{fields[0]}_{fields[1]}")

    # set the new names
    anno.columns = newColumns

    # make sure we don't have duplicates in the new names
    # print(anno.columns)
    assert (numpy.all ([x <= 1 for x in collections.Counter(anno.columns).values()]))

    return anno

# %%
# annoFrame = loadAnnotationFile ("AADR_v54.1_1240K/v54.1_1240K_public.anno")
annoFrame = loadAnnotationFile ("AADR_v54.1_1240K_HO/v54.1_HO_public.anno")

# %%
presentFrame = annoFrame[annoFrame['Date_mean'] <= 0]

# %%
# for (k,v) in collections.Counter(presentFrame['Political_Entity']).items():
#     if (v > 10):
#         print (k,v)

# %%
presentIndividuals = numpy.array (presentFrame['Genetic_ID'])

# %%
indFrame = pandas.read_csv ("AADR_v54.1_1240K_HO/v54.1_HO_public.ind", header=None, delim_whitespace=True)
# annoFrame = loadAnnotationFile ("AADR_v54.1_1240K/v54.1_1240K_public.anno")

# %%
# get only the presentIndividuals
presentMask = [x in presentIndividuals for x in numpy.array(indFrame[0])]
theCounter = collections.Counter(indFrame[presentMask][2])

# %%
sortedCounter = sorted(theCounter.items(), key=lambda x:x[1])

# %%
[x for x in reversed(sortedCounter)]
# Out:
# [('Spanish.HO', 172),
#  ('GWD.DG', 112),
#  ('GWD.SG', 112),
#  ('TSI.SG', 108),
#  ('TSI.DG', 107),
#  ('Han.HO', 107),
#  ('CHS.SG', 106),
#  ('GIH.SG', 105),
#  ('JPT.DG', 104),
#  ('JPT.SG', 104),
#  ('CHS.DG', 103),
#  ('IBS.DG', 103),
#  ('CHB.DG', 103),
#  ('ITU.SG', 103),
#  ('IBS.SG', 103),
#  ('CHB.SG', 103),
#  ('GIH.DG', 102),
#  ('ITU.DG', 102),
#  ('YRI.DG', 101),
#  ('YRI.SG', 101),
#  ('LWK.SG', 101),
#  ('PUR.SG', 100),
#  ('ESN.DG', 99),
#  ('LWK.DG', 99),
#  ('PUR.DG', 99),
#  ('CEU.DG', 99),
#  ('STU.SG', 99),
#  ('ESN.SG', 99),
#  ('CEU.SG', 99),
#  ('CDX.SG', 99),
#  ('STU.DG', 98),
#  ('FIN.DG', 97),
#  ('KHV.SG', 97),
#  ('FIN.SG', 97),
#  ('Tibetan.HO', 97),
#  ('PJL.DG', 96),
#  ('PJL.SG', 96),
#  ('KHV.DG', 95),
#  ('CLM.DG', 94),
#  ('CLM.SG', 94),
#  ('CDX.DG', 93),
#  ('ACB.DG', 92),
#  ('GBR.SG', 92),
#  ('ACB.SG', 92),
#  ('GBR.DG', 90),
#  ('MSL.DG', 85),
#  ('BEB.DG', 85),
#  ('MSL.SG', 85),
#  ('BEB.SG', 85),
#  ('Russian.HO', 71),
#  ('PEL.SG', 69),
#  ('PEL.DG', 68),
#  ('MXL.SG', 64),
#  ('MXL.DG', 62),
#  ('French.HO', 61),
#  ('ASW.SG', 60),
#  ('ASW.DG', 55),
#  ('Bashkir.HO', 53),
#  ('Turkish.HO', 50),
#  ('YRI.HO', 48),
#  ('Han.DG', 45),
#  ('Druze.DG', 41),
#  ('Druze.HO', 39),
#  ('Palestinian.DG', 38),
#  ('Iranian.HO', 38),
#  ('Buryat.HO', 37),
#  ('Palestinian.HO', 34),
#  ('Mongol.HO', 34),
#  ('Nganasan.HO', 33),
#  ('Mordovian.HO', 32),
#  ('Tajik.HO', 31),
#  ('Adygei.HO', 31),
#  ('Japanese.DG', 30),
#  ('Akha.HO', 30),
#  ('Yemeni_Highlands.HO', 29),
#  ('Basque.HO', 29),
#  ('Japanese.HO', 29),
#  ('Sardinian.DG', 28),
#  ('Papuan.DG', 28),
#  ('French.DG', 28),
#  ('Yemeni_Northwest.HO', 28),
#  ('Ignore_YRI_relative.HO', 27),
#  ('Uzbek.HO', 27),
#  ('Tubalar.HO', 27),
#  ('Russian.DG', 26),
#  ('BedouinA.DG', 25),
#  ('Sardinian.HO', 25),
#  ('BedouinA.HO', 25),
#  ('Ulchi.HO', 25),
#  ('Yoruba.DG', 24),
#  ('Mozabite.DG', 24),
#  ('Burusho.DG', 24),
#  ('Brahui.DG', 24),
#  ('Selkup.HO', 24),
#  ('Altaian.HO', 24),
#  ('Iran_Zoroastrian.HO', 24),
#  ('Kalash.DG', 23),
#  ('Basque.DG', 23),
#  ('Burusho.HO', 23),
#  ('Georgian.HO', 23),
#  ('Yakut.DG', 22),
#  ('Makrani.DG', 22),
#  ('Balochi.DG', 22),
#  ('Mandenka.DG', 21),
#  ('Biaka.DG', 21),
#  ('BedouinB.DG', 21),
#  ('Mozabite.HO', 21),
#  ('Yoruba.HO', 21),
#  ('Brahui.HO', 21),
#  ('Mayan.DG', 20),
#  ('Italian_North.DG', 20),
#  ('Qiang.HO', 20),
#  ('Dong.HO', 20),
#  ('Greek.HO', 20),
#  ('Hungarian.HO', 20),
#  ('Italian_North.HO', 20),
#  ('Yakut.HO', 20),
#  ('Biaka.HO', 20),
#  ('Makrani.HO', 20),
#  ('Balochi.HO', 20),
#  ('Chukchi.HO', 20),
#  ('Tuvinian.HO', 20),
#  ('Pathan.DG', 19),
#  ('Ket.HO', 19),
#  ('Zhuang.HO', 19),
#  ('BedouinB.HO', 19),
#  ('Tatar_Siberian.HO', 19),
#  ('Egyptian.HO', 18),
#  ('Mayan.HO', 18),
#  ('Kazakh.HO', 18),
#  ('Orcadian.DG', 17),
#  ('Mulam.HO', 17),
#  ('Maonan.HO', 17),
#  ('Mandenka.HO', 17),
#  ('Kalash.HO', 17),
#  ('Pathan.HO', 17),
#  ('Azeri.HO', 17),
#  ('Iran_Fars.HO', 17),
#  ('Sindhi_Pakistan.DG', 16),
#  ('Yemeni_Desert.HO', 16),
#  ('Yugur.HO', 16),
#  ('Greek.WGA.HO', 16),
#  ('Chuvash.HO', 16),
#  ('Pima.DG', 15),
#  ('Hazara.DG', 15),
#  ('Adygei.DG', 15),
#  ('Yemeni_Desert2.HO', 15),
#  ('Khakass.HO', 15),
#  ('Karelian.HO', 15),
#  ('Mbuti.DG', 14),
#  ('Karitiana.DG', 14),
#  ('Dai.DG', 14),
#  ('Pima.HO', 14),
#  ('Papuan.HO', 14),
#  ('Sindhi_Pakistan.HO', 14),
#  ('Hazara.HO', 14),
#  ('Yukagir_Tundra.HO', 14),
#  ('Ossetian.HO', 14),
#  ('Karakalpak.HO', 14),
#  ('PEL_oAfrican.DG', 13),
#  ('PEL_SomeAfrican.SG', 13),
#  ('Kyrgyz_China.HO', 13),
#  ('Somali.HO', 13),
#  ('Orcadian.HO', 13),
#  ('Dungan.HO', 13),
#  ('Ukrainian.HO', 13),
#  ('Tatar_Kazan.HO', 13),
#  ('Yi.DG', 12),
#  ('Uyghur.DG', 12),
#  ('Tu.DG', 12),
#  ('She.DG', 12),
#  ('Miao.DG', 12),
#  ('Tofalar.HO', 12),
#  ('Icelandic.HO', 12),
#  ('AfricanAmericans.HO', 12),
#  ('Masai.HO', 12),
#  ('Karitiana.HO', 12),
#  ('Eskimo_Naukan.HO', 12),
#  ('Karachai.HO', 12),
#  ('Tujia.DG', 11),
#  ('Oroqen.DG', 11),
#  ('Naxi.DG', 11),
#  ('Assyrian.HO', 11),
#  ('Lebanese_Muslim.HO', 11),
#  ('Sicilian.HO', 11),
#  ('Norwegian.HO', 11),
#  ('Khomani.HO', 11),
#  ('Malawi_Chewa.HO', 11),
#  ('UBR.SG', 10),
#  ('Surui.DG', 10),
#  ('RIA.SG', 10),
#  ('RAJ.SG', 10),
#  ('Nasioi.DG', 10),
#  ('ILA.SG', 10),
#  ('Hezhen.DG', 10),
#  ('China_Lahu.DG', 10),
#  ('Kuy_Suay.HO', 10),
#  ('Micronesian.HO', 10),
#  ('Hmong.HO', 10),
#  ('Lawa.HO', 10),
#  ('Karen_Sgaw.HO', 10),
#  ('Tai_Lue.HO', 10),
#  ('Khmer.HO', 10),
#  ('Htin_Mal.HO', 10),
#  ('Mon.HO', 10),
#  ('Mlabri.HO', 10),
#  ('Nyah_Kur.HO', 10),
#  ('Romanian.HO', 10),
#  ('Vietnamese.HO', 10),
#  ('Murut.HO', 10),
#  ('Moroccan.HO', 10),
#  ('Kankanaey.HO', 10),
#  ('Dusun.HO', 10),
#  ('Burmese.HO', 10),
#  ('Bonan.HO', 10),
#  ('Gelao.HO', 10),
#  ('Croatian.HO', 10),
#  ('Kusunda.HO', 10),
#  ('Mixtec.HO', 10),
#  ('Zapotec.HO', 10),
#  ('Thai.HO', 10),
#  ('English.HO', 10),
#  ('Czech.HO', 10),
#  ('Ami.HO', 10),
#  ('Estonian.HO', 10),
#  ('Belarusian.HO', 10),
#  ('Kalmyk.HO', 10),
#  ('Armenian.HO', 10),
#  ('Balkar.HO', 10),
#  ('Lithuanian.HO', 10),
#  ('Bulgarian.HO', 10),
#  ('Mixe.HO', 10),
#  ('Tu.HO', 10),
#  ('She.HO', 10),
#  ('Dai.HO', 10),
#  ('Uyghur.HO', 10),
#  ('Miao.HO', 10),
#  ('Yi.HO', 10),
#  ('Tujia.HO', 10),
#  ('Nasioi.HO', 10),
#  ('Mbuti.HO', 10),
#  ('Udmurt.HO', 10),
#  ('Tatar_Mishar.HO', 10),
#  ('Nogai_Stavropol.HO', 10),
#  ('Moldavian.HO', 10),
#  ('Veps.HO', 10),
#  ('Ingushian.HO', 10),
#  ('Lak.HO', 10),
#  ('Tabasaran.HO', 10),
#  ('Khamnegan.HO', 10),
#  ('Nanai.HO', 10),
#  ('Nivh.HO', 10),
#  ('Malawi_Tumbuka.HO', 10),
#  ('Xibo.DG', 9),
#  ('VLR.SG', 9),
#  ('Ju_hoan_North.DG', 9),
#  ('Daur.DG', 9),
#  ('Cambodian.DG', 9),
#  ('Maniq.HO', 9),
#  ('Malay.HO', 9),
#  ('Lebanese_Christian.HO', 9),
#  ('Kyrgyz_Kyrgyzstan.HO', 9),
#  ('Jew_Iranian.HO', 9),
#  ('Jew_Libyan.HO', 9),
#  ('Atayal.HO', 9),
#  ('Nogai_Karachay_Cherkessia.HO', 9),
#  ('Lezgin.HO', 9),
#  ('Chechen.HO', 9),
#  ('Jordanian.HO', 9),
#  ('Naxi.HO', 9),
#  ('Daur.HO', 9),
#  ('Oroqen.HO', 9),
#  ('Koryak.HO', 9),
#  ('Ignore_Tubalar.HO', 9),
#  ('Kabardinian.HO', 9),
#  ('Gagauz.HO', 9),
#  ('Circassian.HO', 9),
#  ('Malawi_Yao.HO', 9),
#  ('Piapoco.DG', 8),
#  ('Mongola.DG', 8),
#  ('BIR.SG', 8),
#  ('BantuKenya.DG', 8),
#  ('Iranian_Bandari.HO', 8),
#  ('Salar.HO', 8),
#  ('Kazakh_China.HO', 8),
#  ('Cypriot.HO', 8),
#  ('Mansi.HO', 8),
#  ('Jew_Yemenite.HO', 8),
#  ('Ignore_Turkish.HO', 8),
#  ('Jew_Turkish.HO', 8),
#  ('Tunisian.HO', 8),
#  ('Maltese.HO', 8),
#  ('Luo.HO', 8),
#  ('Esan.HO', 8),
#  ('Mende.HO', 8),
#  ('Luhya.HO', 8),
#  ('Punjabi.HO', 8),
#  ('Kinh.HO', 8),
#  ('Kumyk.HO', 8),
#  ('Abkhasian.HO', 8),
#  ('Saudi.HO', 8),
#  ('Lebanese.HO', 8),
#  ('Syrian.HO', 8),
#  ('China_Lahu.HO', 8),
#  ('Hezhen.HO', 8),
#  ('Surui.HO', 8),
#  ('Cambodian.HO', 8),
#  ('Ignore_Hazara.HO', 8),
#  ('Ignore_Ulchi.HO', 8),
#  ('Even.HO', 8),
#  ('Ukrainian_North.HO', 8),
#  ('Kurd.HO', 8),
#  ('Khakass_Kachin.HO', 8),
#  ('Abazin.HO', 8),
#  ('Ezid.HO', 8),
#  ('Evenk_Transbaikal.HO', 8),
#  ('Kaitag.HO', 8),
#  ('Avar.HO', 8),
#  ('Darginian.HO', 8),
#  ('Armenian_Hemsheni.HO', 8),
#  ('Altaian_Chelkan.HO', 8),
#  ('YRI_o.SG', 7),
#  ('Dongxiang.HO', 7),
#  ('Tamang.HO', 7),
#  ('Ignore_Moroccan.HO', 7),
#  ('Aleut.HO', 7),
#  ('Jew_Georgian.HO', 7),
#  ('Algerian.HO', 7),
#  ('Ethiopia_BetaIsrael.HO', 7),
#  ('Jew_Tunisian.HO', 7),
#  ('Jew_Ashkenazi.HO', 7),
#  ('Bolivian.HO', 7),
#  ('BEB.HO', 7),
#  ('Finnish.HO', 7),
#  ('YRI_o.HO', 7),
#  ('Xibo.HO', 7),
#  ('Eskimo_ChaplinSireniki.HO', 7),
#  ('Shor_Mountain.HO', 7),
#  ('YRI_o.DG', 6),
#  ('ONG.SG', 6),
#  ('Ignore_Pathan_o.DG', 6),
#  ('Ignore_Adygei_duplicate.HO', 6),
#  ('Magar.HO', 6),
#  ('Jew_Moroccan.HO', 6),
#  ('Saharawi.HO', 6),
#  ('Jew_Iraqi.HO', 6),
#  ('Albanian.HO', 6),
#  ('Gambian.HO', 6),
#  ('Korean.HO', 6),
#  ('Turkmen.HO', 6),
#  ('Yemeni.HO', 6),
#  ('BantuKenya.HO', 6),
#  ('Ignore_Mozabite.HO', 6),
#  ('Mongola.HO', 6),
#  ('Ignore_Pathan_o.HO', 6),
#  ('Ignore_Sindhi.HO', 6),
#  ('Itelmen.HO', 6),
#  ('Ignore_Yukagir_Tundra_PCA_outlier.HO', 6),
#  ('Ignore_Eskimo.HO', 6),
#  ('Besermyan.HO', 6),
#  ('Russian_Archangelsk_Krasnoborsky.HO', 6),
#  ('Nogai_Astrakhan.HO', 6),
#  ('Shor_Khakassia.HO', 6),
#  ('Kubachinian.HO', 6),
#  ('ASW_oNativeAmerican.DG', 5),
#  ('Ignore_Sindhi_1.DG', 5),
#  ('Ignore_Hazara_1.DG', 5),
#  ('BantuSA.DG', 5),
#  ('ASW_oNativeAmerican.SG', 5),
#  ('Tagalog.HO', 5),
#  ('Libyan.HO', 5),
#  ('Rai.HO', 5),
#  ('Gurung.HO', 5),
#  ('Tharu.HO', 5),
#  ('Turkish_Balikesir.HO', 5),
#  ('Jew_Cochin.HO', 5),
#  ('GujaratiC.HO', 5),
#  ('GujaratiB.HO', 5),
#  ('GujaratiD.HO', 5),
#  ('Spanish_North.HO', 5),
#  ('Berber.WGA.HO', 5),
#  ('Afar.WGA.HO', 5),
#  ('Ignore_Australian.HO', 5),
#  ('BantuSA.HO', 5),
#  ('Ju_hoan_North.HO', 5),
#  ('Ignore_Yakut.HO', 5),
#  ('Ignore_Makrani.HO', 5),
#  ('Yukagir_Forest.HO', 5),
#  ('Tatar_Siberian_Zabolotniye.HO', 5),
#  ('Russian_Archangelsk_Pinezhsky.HO', 5),
#  ('Russian_Archangelsk_Leshukonsky.HO', 5),
#  ('Evenk_FarEast.HO', 5),
#  ('PUR_oAfrica.DG', 4),
#  ('KHV_o.DG', 4),
#  ('PUR_oAfrica.SG', 4),
#  ('KHV_o.SG', 4),
#  ('JAR.SG', 4),
#  ('Ignore_Palestinian.DG', 4),
#  ('Ignore_Makrani.DG', 4),
#  ('Dinka.DG', 4),
#  ('Buryat.SG', 4),
#  ('Visayan.HO', 4),
#  ('Tibetan_Yunnan.HO', 4),
#  ('Sherpa.HO', 4),
#  ('Li.HO', 4),
#  ('Newar.HO', 4),
#  ('Bahun.HO', 4),
#  ('Italian_South.HO', 4),
#  ('GujaratiA.HO', 4),
#  ('Scottish.HO', 4),
#  ('Quechua.HO', 4),
#  ('Dolgan.HO', 4),
#  ('Ignore_Egyptian.HO', 4),
#  ('Assyrian.WGA.HO', 4),
#  ('Hadza1.HO', 4),
#  ('Kikuyu.HO', 4),
#  ('Piapoco.HO', 4),
#  ('Ignore_Palestinian.HO', 4),
#  ('Ignore_Palestinian_relative.HO', 4),
#  ('Ignore_Sindhi_Pakistan_o.HO', 4),
#  ('Ignore_Balochi.HO', 4),
#  ('Ignore_Koryak.HO', 4),
#  ('Ignore_Chukchi.HO', 4),
#  ('Kyrgyz_Tajikistan.HO', 4),
#  ('Malawi_Ngoni.HO', 4),
#  ('Uzbek.SG', 3),
#  ('Uyghur.SG', 3),
#  ('Tajik.SG', 3),
#  ('Punjabi.DG', 3),
#  ('Palestinian_oAfrican.DG', 3),
#  ('MXL_oEuropean.SG', 3),
#  ('Mozabite_oSubSaharan.DG', 3),
#  ('Mixe.DG', 3),
#  ('Mayan_o2.DG', 3),
#  ('Kazakh.SG', 3),
#  ('Karakalpak.SG', 3),
#  ('Jordanian.DG', 3),
#  ('Ignore_Yakut_1.DG', 3),
#  ('Ignore_Sindhi_Pakistan_o.DG', 3),
#  ('Ignore_Palestinian(relative).DG', 3),
#  ('Ignore_Mandenka(relative).DG', 3),
#  ('Ignore_Brahui.DG', 3),
#  ('Ignore_Biaka.DG', 3),
#  ('Ignore_BantuKenya.DG', 3),
#  ('Hazara.SG', 3),
#  ('Balochi_oAfrica.DG', 3),
#  ('Eritrea.HO', 3),
#  ('Enets.HO', 3),
#  ('Zhuang_outlier.HO', 3),
#  ('Ignore_Jew_Iraqi.HO', 3),
#  ('Datog.HO', 3),
#  ('Shaigi.WGA.HO', 3),
#  ('Azeri.WGA.HO', 3),
#  ('Ain_Touta.WGA.HO', 3),
#  ('Armenian.WGA.HO', 3),
#  ('Australian.HO', 3),
#  ('Ignore_BantuKenya.HO', 3),
#  ('Ignore_Basque.HO', 3),
#  ('Ignore_Mongola.HO', 3),
#  ('Ignore_Mandenka_relative.HO', 3),
#  ('Ignore_Mayan.HO', 3),
#  ('Palestinian_oAfrican.HO', 3),
#  ('Ignore_Druze.HO', 3),
#  ('Ignore_Papuan_discovery.HO', 3),
#  ('Ignore_Biaka.HO', 3),
#  ('Ignore_Brahui.HO', 3),
#  ('Chukchi1.HO', 3),
#  ('Todzin.HO', 3),
#  ('Ignore_Evenk_PCA_outlier.HO', 3),
#  ('Negidal.HO', 3),
#  ('Ignore_Iran_Zoroastrian_PCA_outlier.HO', 3),
#  ('MXL_oEuropean.DG', 2),
#  ('IBS_o1.DG', 2),
#  ('ACB_o1.DG', 2),
#  ('FIN_o.DG', 2),
#  ('IBS_CanaryIslands.DG', 2),
#  ('STU_o1.DG', 2),
#  ('PEL_oHighEuropean.DG', 2),
#  ('STU_o2.DG', 2),
#  ('CHS_o.DG', 2),
#  ('Yadava.DG', 2),
#  ('Ulchi.DG', 2),
#  ('Tuscan_1.DG', 2),
#  ('Turkmen.SG', 2),
#  ('Turkish.DG', 2),
#  ('Tubalar.DG', 2),
#  ('Thai.DG', 2),
#  ('Teleut.SG', 2),
#  ('Tatar_Volga.SG', 2),
#  ('Tatar_Tomsk.SG', 2),
#  ('Tatar_Irtysh_Barabinsk.SG', 2),
#  ('Tajik.DG', 2),
#  ('STU_o2.SG', 2),
#  ('STU_o1.SG', 2),
#  ('Spanish.DG', 2),
#  ('Saharawi.DG', 2),
#  ('Saami.DG', 2),
#  ('Russia_NorthOssetian.DG', 2),
#  ('Russia_Abkhasian.DG', 2),
#  ('Quechua.DG', 2),
#  ('PEL_oHighEuropean.SG', 2),
#  ('Mexico_Zapotec.DG', 2),
#  ('Mende.DG', 2),
#  ('Masai.DG', 2),
#  ('Mansi.DG', 2),
#  ('Mala.DG', 2),
#  ('Madiga.DG', 2),
#  ('Luo.DG', 2),
#  ('Luhya.DG', 2),
#  ('Lezgin.DG', 2),
#  ('Lemande.DG', 2),
#  ('Kyrgyz_Kyrgyzstan.SG', 2),
#  ('Kyrgyz_Kyrgyzstan.DG', 2),
#  ('Kusunda.DG', 2),
#  ('Koryak.SG', 2),
#  ('Korean.DG', 2),
#  ('Kinh.DG', 2),
#  ('Khomani_San.DG', 2),
#  ('Kapu.DG', 2),
#  ('Kalmyk.SG', 2),
#  ('Jew_Yemenite.DG', 2),
#  ('Jew_Iraqi.DG', 2),
#  ('Italian_Sardinian.DG', 2),
#  ('Irula.DG', 2),
#  ('Iranian.DG', 2),
#  ('Igorot.DG', 2),
#  ('Ignore_Yoruba(discovery).DG', 2),
#  ('Ignore_Yakut_2.DG', 2),
#  ('Ignore_Xibo.DG', 2),
#  ('Ignore_Sardinian(discovery).DG', 2),
#  ('Ignore_Papuan(discovery).DG', 2),
#  ('Ignore_Papuan_discovery.DG', 2),
#  ('Ignore_Mozabite.DG', 2),
#  ('Ignore_Mongola.DG', 2),
#  ('Ignore_MbutiPygmy(relative).DG', 2),
#  ('Ignore_Mbuti(discovery).DG', 2),
#  ('Ignore_Mandenka.DG', 2),
#  ('Ignore_Karitiana(discovery).DG', 2),
#  ('Ignore_Ju_hoan_North(discovery).DG', 2),
#  ('Ignore_Han(discovery).DG', 2),
#  ('Ignore_French(discovery).DG', 2),
#  ('Ignore_Druze.DG', 2),
#  ('Ignore_Cambodian.DG', 2),
#  ('Ignore_Burusho.DG', 2),
#  ('Ignore_Basque.DG', 2),
#  ('Ignore_BantuKenya(relative).DG', 2),
#  ('Ignore_Adygei.DG', 2),
#  ('Igbo.DG', 2),
#  ('Icelandic.DG', 2),
#  ('IBS_o1.SG', 2),
#  ('IBS_CanaryIslands.SG', 2),
#  ('Hungarian.DG', 2),
#  ('Georgian.DG', 2),
#  ('Gambian.DG', 2),
#  ('Finnish.DG', 2),
#  ('FIN_o.SG', 2),
#  ('Even.DG', 2),
#  ('Estonian.DG', 2),
#  ('Eskimo_Sireniki.DG', 2),
#  ('Eskimo_Naukan.DG', 2),
#  ('Esan.DG', 2),
#  ('English.DG', 2),
#  ('Dusun.DG', 2),
#  ('Dungan.SG', 2),
#  ('Cretan.DG', 2),
#  ('CHS_o.SG', 2),
#  ('Chipewyan.DG', 2),
#  ('Burmese.DG', 2),
#  ('Bulgarian.DG', 2),
#  ('Brahmin.DG', 2),
#  ('Bougainville.DG', 2),
#  ('Bengali.DG', 2),
#  ('Bashkir.SG', 2),
#  ('BantuTswana.DG', 2),
#  ('BantuSA_Herero.DG', 2),
#  ('BantuHerero.DG', 2),
#  ('Australian.DG', 2),
#  ('Armenian.DG', 2),
#  ('Ami.DG', 2),
#  ('Aleut.DG', 2),
#  ('ACB_o1.SG', 2),
#  ('Ignore_Eskimo_Naukan_duplicate.HO', 2),
#  ('Ignore_Hadza_Henn_relative.HO', 2),
#  ('hg19ref.HO', 2),
#  ('Ilocano.HO', 2),
#  ('Ignore_Jew_Georgian.HO', 2),
#  ('Ignore_Jew_Ashkenazi.HO', 2),
#  ('IBS_CanaryIslands.HO', 2),
#  ('Ignore_Greek.HO', 2),
#  ('Russia_NorthOssetian.HO', 2),
#  ('Ignore_Saudi.HO', 2),
#  ('Ignore_YRI.HO', 2),
#  ('Greek_outlier.WGA.HO', 2),
#  ('Georgian.WGA.HO', 2),
#  ('Kurd.WGA.HO', 2),
#  ('Ignore_BantuKenya_relative.HO', 2),
#  ('Ignore_Adygei.HO', 2),
#  ('Ignore_Xibo.HO', 2),
#  ('Ignore_Mongola_discovery.HO', 2),
#  ('Ignore_Ju_hoan_North_discovery.HO', 2),
#  ('Namibia_Bantu_Herero.HO', 2),
#  ('Ignore_Karitiana_discovery.HO', 2),
#  ('Ignore_YRI_discovery.HO', 2),
#  ('Ignore_Mandenka.HO', 2),
#  ('Ignore_Han_discovery.HO', 2),
#  ('Ignore_Cambodian.HO', 2),
#  ('Italian_Sardinian.HO', 2),
#  ('Ignore_BedouinB.HO', 2),
#  ('Ignore_French_discovery.HO', 2),
#  ('Ignore_French.HO', 2),
#  ('Ignore_MbutiPygmy_relative.HO', 2),
#  ('Ignore_Burusho.HO', 2),
#  ('Tlingit.HO', 2),
#  ('Ignore_Nganasan.HO', 2),
#  ('Ignore_Russian_PCA_outlier.HO', 2),
#  ('Ignore_Khaka_PCA_outlier.HO', 2),
#  ('Abazin_outlier.HO', 2),
#  ('Ignore_Buryat_PCA_outlier.HO', 2),
#  ('Iran_Zoroastrian_outlier.HO', 2),
#  ('GWD_oEuropean.DG', 1),
#  ('YRI_relative.DG', 1),
#  ('Ignore_BEB_o.DG', 1),
#  ('ASW_oEuropean.DG', 1),
#  ('ACB_o3.DG', 1),
#  ('PEL_oEastAsian.DG', 1),
#  ('GIH_o.DG', 1),
#  ('ACB_o2.DG', 1),
#  ('PEL_oHighAfrican.DG', 1),
#  ('PUR_oEuropean.DG', 1),
#  ('Yukpa.SG', 1),
#  ('YRI_relative.SG', 1),
#  ('Tsimshian.SG', 1),
#  ('Tajik_o.SG', 1),
#  ('Somali.DG', 1),
#  ('Samaritan.DG', 1),
#  ('Relli_2.DG', 1),
#  ('Relli_1.DG', 1),
#  ('Quechua_oEuropean.DG', 1),
#  ('PUR_oEuropean.SG', 1),
#  ('Punjabi_o.DG', 1),
#  ('PUN.SG', 1),
#  ('Polish.DG', 1),
#  ('PEL_oHighAfrican.SG', 1),
#  ('PEL_oEastAsian.SG', 1),
#  ('Norwegian.DG', 1),
#  ('Nahua.DG', 1),
#  ('Mixtec_2.DG', 1),
#  ('Mixtec_1.DG', 1),
#  ('Mayan.SG', 1),
#  ('Mari.SG', 1),
#  ('Maori.DG', 1),
#  ('Malaysia_Jehai.SG', 1),
#  ('Malaysia_Jehai_dup.JHM06.SG', 1),
#  ('Kongo.DG', 1),
#  ('Khonda_Dora.DG', 1),
#  ('Karitiana.SG', 1),
#  ('Itelmen.DG', 1),
#  ('Indian.SG', 1),
#  ('Ignore_Sindhi_2.DG', 1),
#  ('Ignore_Russian.DG', 1),
#  ('Ignore_Piapoco.DG', 1),
#  ('Ignore_Pathan.DG', 1),
#  ('Ignore_Papuan.DG', 1),
#  ('Ignore_Palestinian_relative.DG', 1),
#  ('Ignore_Nasioi_Discovery.DG', 1),
#  ('Ignore_Mongola(discovery).DG', 1),
#  ('Ignore_Makrani_o.DG', 1),
#  ('Ignore_Kalash.DG', 1),
#  ('Ignore_Italian_North.DG', 1),
#  ('Ignore_Hezhen.DG', 1),
#  ('Ignore_Hazara_2.DG', 1),
#  ('Ignore_French.DG', 1),
#  ('Ignore_Druze_o.DG', 1),
#  ('Ignore_BedouinB_2.DG', 1),
#  ('Ignore_BedouinB_1.DG', 1),
#  ('Ignore_BEB_o.SG', 1),
#  ('Huichol.SG', 1),
#  ('Href.REF', 1),
#  ('Hawaiian.DG', 1),
#  ('GWD_oEuropean.SG', 1),
#  ('Greek_2.DG', 1),
#  ('Greek_1.DG', 1),
#  ('Gorilla.REF', 1),
#  ('GIH_o.SG', 1),
#  ('French_o.DG', 1),
#  ('Finnish_o.DG', 1),
#  ('Finland_Saami_Modern.SG', 1),
#  ('Even_o.DG', 1),
#  ('Eskimo_Chaplin.DG', 1),
#  ('Daur_o.DG', 1),
#  ('Czech.DG', 1),
#  ('Cree2.DG', 1),
#  ('Cree1.DG', 1),
#  ('Chukchi.DG', 1),
#  ('Chimp.REF', 1),
#  ('Chechen.DG', 1),
#  ('Chane.DG', 1),
#  ('Brahui_o.DG', 1),
#  ('BIR_o.SG', 1),
#  ('Bergamo.DG', 1),
#  ('BEN.SG', 1),
#  ('Bashkir_o.SG', 1),
#  ('BantuSA_Ovambo.DG', 1),
#  ('Balochi_oEastAsian.DG', 1),
#  ('Aymara.SG', 1),
#  ('Avar.SG', 1),
#  ('Atayal.DG', 1),
#  ('ASW_oEuropean.SG', 1),
#  ('Ancestor.REF', 1),
#  ('Altaian.SG', 1),
#  ('Altaian.DG', 1),
#  ('Altaian_o.SG', 1),
#  ('Aleut_o1.DG', 1),
#  ('Aleut_o.DG', 1),
#  ('Albanian.DG', 1),
#  ('Adygei_o.DG', 1),
#  ('ACB_o2.SG', 1),
#  ('ACB_o3.SG', 1),
#  ('Spanish_Lleida.HO', 1),
#  ('Ignore_Yemeni_Northwest__PCA_outlier.HO', 1),
#  ('Yemeni_Highlands_Raymah.HO', 1),
#  ('Ignore_Akha_ADMIXTURE_outlier.HO', 1),
#  ('Ignore_Nganasan_PCA_outlier.HO', 1),
#  ('Ignore_Yemeni_PCA_outlier.HO', 1),
#  ('Ignore_Nasoi_Discovery.HO', 1),
#  ('Ignore_Italian_Sardinian_discovery.HO', 1),
#  ('Ignore_MbutiPygmy_discovery.HO', 1),
#  ('Ignore_Hadza_Henn_duplicate.WGA.HO', 1),
#  ('Ignore_Australian_ECCAC_PCA_outlier.HO', 1),
#  ('Orangutan.HO', 1),
#  ('Gorilla.HO', 1),
#  ('Tofalar_oEuropean.HO', 1),
#  ('Ignore_Italian_South_1d.rel.HO', 1),
#  ('Ignore_Newar.HO', 1),
#  ('Ignore_Tamang.HO', 1),
#  ('Ignore_Bahun.HO', 1),
#  ('Ignore_Kyrgyz_Kyrgyzstan.HO', 1),
#  ('Ignore_Turkish_Balikesir_PCA_outlier_vs_rest.HO', 1),
#  ('Ignore_Saharawi.HO', 1),
#  ('Ignore_Jew_Moroccan.HO', 1),
#  ('Ignore_Eskimo_PCA_outlier.HO', 1),
#  ('Ignore_Jew_Turkish.HO', 1),
#  ('Ignore_Jew_Iranian.HO', 1),
#  ('Ignore_Masai.HO', 1),
#  ('Ignore_Luo.HO', 1),
#  ('Ignore_BEB_o.HO', 1),
#  ('GIH_o.HO', 1),
#  ('FIN_o.HO', 1),
#  ('Ignore_Spanish.HO', 1),
#  ('Ignore_Adygei_relative.of.HGDP01382.HO', 1),
#  ('Ignore_Atayal.HO', 1),
#  ('Quechua_oEuropean.HO', 1),
#  ('Turkmen_outlier.HO', 1),
#  ('Ignore_Dolgan.HO', 1),
#  ('Ignore_Kumyk.HO', 1),
#  ('Ignore_Lezgin.HO', 1),
#  ('Russia_Abkhasian.HO', 1),
#  ('Ignore_Jordanian.HO', 1),
#  ('Ignore_Iranian.HO', 1),
#  ('YRI_relative.HO', 1),
#  ('Assyrian.WGA_outlier.HO', 1),
#  ('Uzbek_outlier.WGA.HO', 1),
#  ('Saami.WGA.HO', 1),
#  ('Hadza1_outlier.HO', 1),
#  ('Ignore_Hadza.HO', 1),
#  ('Marmoset.HO', 1),
#  ('Macaque.HO', 1),
#  ('Vindija_light.HO', 1),
#  ('Primate_Chimp.HO', 1),
#  ('Ignore_Hezhen.HO', 1),
#  ('Ignore_Italian_North.HO', 1),
#  ('BantuSA_Ovambo.HO', 1),
#  ('Ignore_Russian.HO', 1),
#  ('Ignore_Piapoco.HO', 1),
#  ('Ignore_Sardinian_discovery.HO', 1),
#  ('Ignore_Papuan.HO', 1),
#  ('French_o.HO', 1),
#  ('Ignore_Nasioi_Discovery.HO', 1),
#  ('Ignore_Mbuti_discovery.HO', 1),
#  ('Ignore_Kalash.HO', 1),
#  ('Ignore_Kalash_PCA_outlier.HO', 1),
#  ('Ignore_Pathan.HO', 1),
#  ('Ignore_Eskimo_outlier_groups_with_Naukan.HO', 1),
#  ('Aleut_o1.HO', 1),
#  ('Eskimo_Sireniki.HO', 1),
#  ('Aleut_o.HO', 1),
#  ('Ignore_Even_<0.95_completeness.HO', 1),
#  ('Ignore_Tlingit_relative.HO', 1),
#  ('Ignore_Itelmen.HO', 1),
#  ('Even_o.HO', 1),
#  ('Ignore_Khomani.HO', 1),
#  ('Ignore_Dungan_PCA_outlier.HO', 1),
#  ('Ignore_Todzin_PCA_outlier.HO', 1),
#  ('Ignore_Tatar_Siberian_PCA_outlier.HO', 1),
#  ('Ignore_Russian_<0.95_completeness.HO', 1),
#  ('Ignore_Kurdish_PCA_outlier.HO', 1),
#  ('Khakass_outlier.HO', 1),
#  ('Kabardinian_outlier.HO', 1),
#  ('Ignore_Ezid_<0.95_completeness.HO', 1),
#  ('Avar_outlier2.HO', 1),
#  ('Avar_outlier1.HO', 1),
#  ('Ignore_Negidal_PCA_outlier.HO', 1),
#  ('Ignore_Altaian_PCA_outlier.HO', 1),
#  ('Ignore_Tubalar_PCA_outlier.HO', 1)]
